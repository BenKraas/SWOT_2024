# %% [markdown]
# # Goal
# We have downloaded the data for the focus regions and now want to filter it.
# - We only want to keep the data for the focus region bounding box and a buffer zone around it
# - We keep data that has raised no quality flags
# - We keep data for the "open_water" class (class 4) and the "water_near_land" class (class 3)

# %%
# Standard library imports
from concurrent.futures import ThreadPoolExecutor
from datetime import datetime
import json
from pathlib import Path
import os
import glob
import zipfile
from functools import partial

# Third-party library imports
import geopandas as gpd
import pandas as pd
import contextily as ctx
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import netCDF4
import earthaccess

import gc

# Matplotlib inline magic command
# %matplotlib inline

# Load the configuration file which we created in the previous step
try:
    with open('config.json', 'r') as f:
        config = json.load(f)
except FileNotFoundError:
    print("config.json not found. Please ensure that the 01 notebook's first two code blocks have been run to generate the config.json file.")

# Create output directory if needed
output_dir = Path(config['data_dir']) / 'output'
output_dir.mkdir(exist_ok=True)

# Define class mapping
class_mapping = {3: 'water', 4: 'land'}

print("Libraries loaded and configuration set.")
# Out:
# Libraries loaded and configuration set.

# %%
# This dictionary explicitely outlines the data columns and their data types
# It is mainyl intended to be read and understood by the user.

data_columns = {
    "classification": {
        "type": int,
        "null_value": 255,
        "description": "Flags indicating water detection results.",
    },
    "classification_str": {
        "type": str,
        "null_value": "unknown",
        "value_map": {
            1: "land",
            2: "land_near_water ",
            3: "water_near_land ",
            4: "open_water ",
            5: "dark_water  ",
            6: "low_coh_water_near_land  ",
            7: "open_low_coh_water "
        },
        "description": "Flags indicating water detection results as string.",
    },
    "layover_impact": {
        "type": float,
        "null_value": 9.969209968386869e+36,
        "description": "Estimate of the height error caused by layover, which may not be reliable on a pixel by pixel basis, but may be useful to augment aggregated height uncertainties. ",
    },
    "height": {
        "type": float,
        "null_value": 9.96921e+36,
        "description": "Height of the pixel above the reference ellipsoid.",
    },
    "illumination_time": {
        "type": datetime,
        "null_value": 9.969209968386869e+36,
        "description": "Time of measurement in seconds in the UTC time scale since 1 Jan 2000 00:00:00 UTC. [tai_utc_difference] is the difference between TAI and UTC reference time (seconds) for the first measurement of the data set. If a leap second occurs within the data set, the attribute leap_second is set to the UTC time at which the leap second occurs. ",
    },
	"geolocation_qual": {
        "type": int,
        "null_value": 4294967295,
        "description": "Quality flag for the geolocation quantities in the pixel cloud data",
		"flag_masks": {
            "layover_significant": 1,
            "phase_noise_suspect": 2,
            "phase_unwrapping_suspect": 4,
            "model_dry_tropo_cor_suspect": 8,
            "model_wet_tropo_cor_suspect": 16,
            "iono_cor_gim_ka_suspect": 32,
            "xovercal_suspect": 64,
            "suspect_karin_telem": 1024,
            "medium_phase_suspect": 4096,
            "tvp_suspect": 8192,
            "sc_event_suspect": 16384,
            "small_karin_gap": 32768,
            "specular_ringing_degraded": 524288,
            "model_dry_tropo_cor_missing": 1048576,
            "model_wet_tropo_cor_missing": 2097152,
            "iono_cor_gim_ka_missing": 4194304,
            "xovercal_missing": 8388608,
            "geolocation_is_from_refloc": 16777216,
            "no_geolocation_bad": 33554432,
            "medium_phase_bad": 67108864,
            "tvp_bad": 134217728,
            "sc_event_bad": 268435456,
            "large_karin_gap": 536870912
        }
    },
	"pixc_line_qual": {},
}

# %% [markdown]
# ---

# %%
# Load the bounding box
bbox_path = Path(config['data_dir']) / 'bbox.geojson'
with open(bbox_path, 'r') as f:
    bbox_data = json.load(f)
bbox_gdf = gpd.GeoDataFrame.from_features(bbox_data['features'])

# Get bounds for filtering
min_lat = bbox_gdf.bounds.miny[0]
max_lat = bbox_gdf.bounds.maxy[0]
min_lon = bbox_gdf.bounds.minx[0]
max_lon = bbox_gdf.bounds.maxx[0]

print(f"Bounding box loaded: Lat [{min_lat}, {max_lat}], Lon [{min_lon}, {max_lon}]")
# Out:
# Bounding box loaded: Lat [-0.819408861907936, -0.037710351979959], Lon [36.8584632059703, 37.2444933070158]

# %%
def process_file_fast(file_path, output_path, append=False):
    """
    Process a netCDF file with direct array indexing to minimize memory usage.
    """
    try:
        # Open the dataset
        with xr.open_dataset(file_path, group='pixel_cloud') as ds:
            # Get the coordinates we need
            if 'latitude' not in ds.variables or 'longitude' not in ds.variables:
                print(f"\tSkipping {file_path.name} - missing lat/lon variables")
                return 0
                
            # Get dimensions
            if 'points' in ds.sizes:
                main_dim = 'points'
            else:
                dims = list(ds.sizes.keys())
                print(f"\tAvailable dimensions: {dims}")
                for dim in ['time', 'record']:
                    if dim in dims:
                        main_dim = dim
                        break
                else:
                    # If no recognized dimension, use the largest
                    main_dim = max(ds.sizes.items(), key=lambda x: x[1])[0]
                    
            dim_size = ds.sizes[main_dim]
            print(f"\tUsing dimension '{main_dim}' with {dim_size} points")

            # Get variables we need
            needed_vars = ['latitude', 'longitude', 'classification']
            missing_vars = [var for var in needed_vars if var not in ds.variables]
            if missing_vars:
                print(f"  Skipping {file_path.name} - missing variables: {missing_vars}")
                return 0

            # Direct indexing with numpy for spatial filtering
            lat_array = ds.latitude.values
            lon_array = ds.longitude.values
            class_array = ds.classification.values
            
            # Create a mask for spatial filtering
            spatial_mask = (
                (lat_array >= min_lat) & 
                (lat_array <= max_lat) & 
                (lon_array >= min_lon) & 
                (lon_array <= max_lon)
            )
            
            # Further filter by classification (3 or 4)
            class_mask = np.logical_or(class_array == 3, class_array == 4)
            
            # Combine masks
            final_mask = np.logical_and(spatial_mask, class_mask)
            
            # Count results
            total_points = len(lat_array)
            spatial_points = np.sum(spatial_mask)
            final_points = np.sum(final_mask)
            
            print(f"\tProcessing {file_path.name}: Total={total_points}, In bbox={spatial_points}, Class 3/4={final_points}")
            
            # If we have points, save them
            if final_points > 0:
                # Create a dataframe with only the filtered points
                df = pd.DataFrame({
                    'latitude': lat_array[final_mask],
                    'longitude': lon_array[final_mask],
                    'classification': class_array[final_mask]
                })
                
                # Add classification string
                df['classification_str'] = df['classification'].map(class_mapping)
                
                # Handle appending
                if append and os.path.exists(output_path):
                    # Read existing data
                    try:
                        existing_df = pd.read_parquet(output_path)
                        # Combine with new data
                        combined_df = pd.concat([existing_df, df], ignore_index=True)
                        # Save combined data
                        combined_df.to_parquet(output_path, engine='pyarrow', compression='snappy', index=False)
                    except Exception as append_err:
                        print(f"\tWarning: Could not append to existing file ({str(append_err)}). Creating new file.")
                        df.to_parquet(output_path, engine='pyarrow', compression='snappy', index=False)
                else:
                    # Save directly without append
                    df.to_parquet(output_path, engine='pyarrow', compression='snappy', index=False)
                
                return final_points
            else:
                return 0
                
    except Exception as e:
        print(f"\tError processing {file_path.name}: {str(e)}")
        return 0

# %%
# Get list of files to process
pixel_cloud_dir = Path(config['water_mask_pixel_cloud_dir'])
file_list = list(pixel_cloud_dir.glob('*.nc'))
total_files = len(file_list)
print(f"Found {total_files} files to process")

# Set up output file and directory
output_file = Path(config['output_file'])
output_file.parent.mkdir(exist_ok=True)

# Optional: Process smaller batch for testing
# file_list = file_list[:10]  # Uncomment to test with fewer files
# total_files = len(file_list)

# Initialize counters
total_points = 0
processed_files = 0

# Remove existing output file to start fresh
if output_file.exists():
    output_file.unlink()
    print(f"Removed existing output file: {output_file}")

# Create empty dataframe for accumulating results
all_data = pd.DataFrame()

# Process all files
for i, file_path in enumerate(file_list):
    print(f"\nProcessing file {i+1}/{total_files}: {file_path.name}")
    
    # Process the file
    try:
        points = process_file_fast(file_path, output_file, append=(i > 0))
        total_points += points
        processed_files += 1
    except Exception as e:
        print(f"Error processing file: {str(e)}")
    
    # Clear memory
    gc.collect()
    
    # Status update every 10 files
    if (i+1) % 10 == 0 or (i+1) == total_files:
        print(f"\nStatus: Processed {i+1}/{total_files} files, found {total_points} points so far")

print(f"\nProcessing complete! Found {total_points} points in {processed_files} files.")
# Out:
# Found 148 files to process
#
# Processing file 1/148: SWOT_L2_HR_PIXC_021_165_154R_20240916T093816_20240916T093827_PIC0_01.nc
# Using dimension 'points' with 4681946 points
# Processing SWOT_L2_HR_PIXC_021_165_154R_20240916T093816_20240916T093827_PIC0_01.nc: Total=4681946, In bbox=854814, Class 3/4=11599
#
# Processing file 2/148: SWOT_L2_HR_PIXC_018_012_154R_20240710T081133_20240710T081144_PIC0_01.nc
# Using dimension 'points' with 3471897 points
# Processing SWOT_L2_HR_PIXC_018_012_154R_20240710T081133_20240710T081144_PIC0_01.nc: Total=3471897, In bbox=447, Class 3/4=1
#
# Processing file 3/148: SWOT_L2_HR_PIXC_018_318_156L_20240721T063442_20240721T063453_PIC0_02.nc
# Using dimension 'points' with 8153189 points
# Processing SWOT_L2_HR_PIXC_018_318_156L_20240721T063442_20240721T063453_PIC0_02.nc: Total=8153189, In bbox=3475012, Class 3/4=64776
#
# Processing file 4/148: SWOT_L2_HR_PIXC_018_165_154L_20240715T192302_20240715T192313_PIC0_01.nc
# Using dimension 'points' with 3125903 points
# Processing SWOT_L2_HR_PIXC_018_165_154L_20240715T192302_20240715T192313_PIC0_01.nc: Total=3125903, In bbox=1142818, Class 3/4=22943
#
# Processing file 5/148: SWOT_L2_HR_PIXC_024_165_153R_20241117T235322_20241117T235333_PIC2_01.nc
# Using dimension 'points' with 7343162 points
# Processing SWOT_L2_HR_PIXC_024_165_153R_20241117T235322_20241117T235333_PIC2_01.nc: Total=7343162, In bbox=708163, Class 3/4=29611
#
# Processing file 6/148: SWOT_L2_HR_PIXC_017_012_156R_20240619T112650_20240619T112701_PIC0_01.nc
# Using dimension 'points' with 4692951 points
# Processing SWOT_L2_HR_PIXC_017_012_156R_20240619T112650_20240619T112701_PIC0_01.nc: Total=4692951, In bbox=0, Class 3/4=0
#
# Processing file 7/148: SWOT_L2_HR_PIXC_017_318_156L_20240630T094937_20240630T094948_PIC0_01.nc
# Using dimension 'points' with 6826511 points
# Processing SWOT_L2_HR_PIXC_017_318_156L_20240630T094937_20240630T094948_PIC0_01.nc: Total=6826511, In bbox=2836363, Class 3/4=39395
#
# Processing file 8/148: SWOT_L2_HR_PIXC_020_012_155R_20240821T014152_20240821T014203_PIC0_01.nc
# Using dimension 'points' with 4329219 points
# Processing SWOT_L2_HR_PIXC_020_012_155R_20240821T014152_20240821T014203_PIC0_01.nc: Total=4329219, In bbox=77668, Class 3/4=1073
#
# Processing file 9/148: SWOT_L2_HR_PIXC_026_012_156R_20241224T061233_20241224T061244_PIC2_01.nc
# Using dimension 'points' with 6325054 points
# Processing SWOT_L2_HR_PIXC_026_012_156R_20241224T061233_20241224T061244_PIC2_01.nc: Total=6325054, In bbox=2, Class 3/4=0
#
# Processing file 10/148: SWOT_L2_HR_PIXC_024_012_156R_20241112T124224_20241112T124235_PIC2_01.nc
# Using dimension 'points' with 6174295 points
# Processing SWOT_L2_HR_PIXC_024_012_156R_20241112T124224_20241112T124235_PIC2_01.nc: Total=6174295, In bbox=0, Class 3/4=0
#
# Status: Processed 10/148 files, found 169398 points so far
#
# Processing file 11/148: SWOT_L2_HR_PIXC_017_165_153R_20240624T223747_20240624T223758_PIC0_01.nc
# Using dimension 'points' with 5901928 points
# Processing SWOT_L2_HR_PIXC_017_165_153R_20240624T223747_20240624T223758_PIC0_01.nc: Total=5901928, In bbox=609323, Class 3/4=20755
#
# Processing file 12/148: SWOT_L2_HR_PIXC_022_318_155L_20241012T173453_20241012T173504_PIC0_01.nc
# Using dimension 'points' with 4342384 points
# Processing SWOT_L2_HR_PIXC_022_318_155L_20241012T173453_20241012T173504_PIC0_01.nc: Total=4342384, In bbox=2637210, Class 3/4=51726
#
# Processing file 13/148: SWOT_L2_HR_PIXC_014_012_154R_20240417T211116_20240417T211127_PIC0_01.nc
# Using dimension 'points' with 3244310 points
# Processing SWOT_L2_HR_PIXC_014_012_154R_20240417T211116_20240417T211127_PIC0_01.nc: Total=3244310, In bbox=2636, Class 3/4=13
#
# Processing file 14/148: SWOT_L2_HR_PIXC_020_165_154L_20240826T125310_20240826T125321_PIC0_01.nc
# Using dimension 'points' with 2957384 points
# Processing SWOT_L2_HR_PIXC_020_165_154L_20240826T125310_20240826T125321_PIC0_01.nc: Total=2957384, In bbox=1189876, Class 3/4=24055
#
# Processing file 15/148: SWOT_L2_HR_PIXC_010_318_155L_20240205T083356_20240205T083407_PIC0_01.nc
# Using dimension 'points' with 4434973 points
# Processing SWOT_L2_HR_PIXC_010_318_155L_20240205T083356_20240205T083407_PIC0_01.nc: Total=4434973, In bbox=2764726, Class 3/4=59926
#
# Processing file 16/148: SWOT_L2_HR_PIXC_012_012_154R_20240307T034107_20240307T034118_PIC0_01.nc
# Using dimension 'points' with 3360283 points
# Processing SWOT_L2_HR_PIXC_012_012_154R_20240307T034107_20240307T034118_PIC0_01.nc: Total=3360283, In bbox=2083, Class 3/4=8
#
# Processing file 17/148: SWOT_L2_HR_PIXC_010_012_155R_20240125T101108_20240125T101119_PGC0_01.nc
# Using dimension 'points' with 4053412 points
# Processing SWOT_L2_HR_PIXC_010_012_155R_20240125T101108_20240125T101119_PGC0_01.nc: Total=4053412, In bbox=72978, Class 3/4=554
#
# Processing file 18/148: SWOT_L2_HR_PIXC_015_012_155R_20240508T175630_20240508T175641_PIC0_01.nc
# Using dimension 'points' with 4503094 points
# Processing SWOT_L2_HR_PIXC_015_012_155R_20240508T175630_20240508T175641_PIC0_01.nc: Total=4503094, In bbox=55557, Class 3/4=502
#
# Processing file 19/148: SWOT_L2_HR_PIXC_014_012_155R_20240417T211126_20240417T211137_PIC0_01.nc
# Using dimension 'points' with 4157722 points
# Processing SWOT_L2_HR_PIXC_014_012_155R_20240417T211126_20240417T211137_PIC0_01.nc: Total=4157722, In bbox=58244, Class 3/4=456
#
# Processing file 20/148: SWOT_L2_HR_PIXC_021_318_155L_20240921T204948_20240921T204959_PIC0_01.nc
# Using dimension 'points' with 4488303 points
# Processing SWOT_L2_HR_PIXC_021_318_155L_20240921T204948_20240921T204959_PIC0_01.nc: Total=4488303, In bbox=2740668, Class 3/4=55237
#
# Status: Processed 20/148 files, found 382630 points so far
#
# Processing file 21/148: SWOT_L2_HR_PIXC_015_165_153R_20240514T050738_20240514T050749_PIC0_01.nc
# Using dimension 'points' with 7654740 points
# Processing SWOT_L2_HR_PIXC_015_165_153R_20240514T050738_20240514T050749_PIC0_01.nc: Total=7654740, In bbox=705331, Class 3/4=35779
#
# Processing file 22/148: SWOT_L2_HR_PIXC_012_165_154R_20240312T145233_20240312T145245_PIC0_01.nc
# Using dimension 'points' with 4842167 points
# Processing SWOT_L2_HR_PIXC_012_165_154R_20240312T145233_20240312T145245_PIC0_01.nc: Total=4842167, In bbox=976617, Class 3/4=12538
#
# Processing file 23/148: SWOT_L2_HR_PIXC_020_012_154R_20240821T014142_20240821T014153_PIC0_01.nc
# Using dimension 'points' with 4065852 points
# Processing SWOT_L2_HR_PIXC_020_012_154R_20240821T014142_20240821T014153_PIC0_01.nc: Total=4065852, In bbox=1112, Class 3/4=4
#
# Processing file 24/148: SWOT_L2_HR_PIXC_014_165_153R_20240423T082234_20240423T082245_PIC0_01.nc
# Using dimension 'points' with 8887971 points
# Processing SWOT_L2_HR_PIXC_014_165_153R_20240423T082234_20240423T082245_PIC0_01.nc: Total=8887971, In bbox=871624, Class 3/4=66248
#
# Processing file 25/148: SWOT_L2_HR_PIXC_025_165_154R_20241208T203836_20241208T203847_PIC2_01.nc
# Using dimension 'points' with 5070424 points
# Processing SWOT_L2_HR_PIXC_025_165_154R_20241208T203836_20241208T203847_PIC2_01.nc: Total=5070424, In bbox=967333, Class 3/4=12243
#
# Processing file 26/148: SWOT_L2_HR_PIXC_025_012_155R_20241203T092719_20241203T092730_PIC2_01.nc
# Using dimension 'points' with 4339706 points
# Processing SWOT_L2_HR_PIXC_025_012_155R_20241203T092719_20241203T092730_PIC2_01.nc: Total=4339706, In bbox=72685, Class 3/4=580
#
# Processing file 27/148: SWOT_L2_HR_PIXC_009_318_155L_20240115T114850_20240115T114901_PIC0_01.nc
# Using dimension 'points' with 5305592 points
# Processing SWOT_L2_HR_PIXC_009_318_155L_20240115T114850_20240115T114901_PIC0_01.nc: Total=5305592, In bbox=3124706, Class 3/4=85576
#
# Processing file 28/148: SWOT_L2_HR_PIXC_016_318_156L_20240609T130433_20240609T130444_PIC0_01.nc
# Using dimension 'points' with 7753548 points
# Processing SWOT_L2_HR_PIXC_016_318_156L_20240609T130433_20240609T130444_PIC0_01.nc: Total=7753548, In bbox=3232503, Class 3/4=46422
#
# Processing file 29/148: SWOT_L2_HR_PIXC_015_318_156L_20240519T161928_20240519T161939_PIC0_01.nc
# Using dimension 'points' with 9273948 points
# Processing SWOT_L2_HR_PIXC_015_318_156L_20240519T161928_20240519T161939_PIC0_01.nc: Total=9273948, In bbox=3908184, Class 3/4=87975
#
# Processing file 30/148: SWOT_L2_HR_PIXC_012_012_156R_20240307T034127_20240307T034138_PIC0_01.nc
# Using dimension 'points' with 5233919 points
# Processing SWOT_L2_HR_PIXC_012_012_156R_20240307T034127_20240307T034138_PIC0_01.nc: Total=5233919, In bbox=0, Class 3/4=0
#
# Status: Processed 30/148 files, found 729995 points so far
#
# Processing file 31/148: SWOT_L2_HR_PIXC_023_318_156L_20241102T142007_20241102T142018_PIC2_01.nc
# Using dimension 'points' with 6724573 points
# Processing SWOT_L2_HR_PIXC_023_318_156L_20241102T142007_20241102T142018_PIC2_01.nc: Total=6724573, In bbox=2899488, Class 3/4=40688
#
# Processing file 32/148: SWOT_L2_HR_PIXC_009_012_154R_20240104T132552_20240104T132603_PIC0_01.nc
# Using dimension 'points' with 3017591 points
# Processing SWOT_L2_HR_PIXC_009_012_154R_20240104T132552_20240104T132603_PIC0_01.nc: Total=3017591, In bbox=1499, Class 3/4=5
#
# Processing file 33/148: SWOT_L2_HR_PIXC_013_012_156R_20240328T002630_20240328T002641_PIC0_01.nc
# Using dimension 'points' with 5429058 points
# Processing SWOT_L2_HR_PIXC_013_012_156R_20240328T002630_20240328T002641_PIC0_01.nc: Total=5429058, In bbox=0, Class 3/4=0
#
# Processing file 34/148: SWOT_L2_HR_PIXC_020_318_156L_20240901T000451_20240901T000502_PIC0_01.nc
# Using dimension 'points' with 6755984 points
# Processing SWOT_L2_HR_PIXC_020_318_156L_20240901T000451_20240901T000502_PIC0_01.nc: Total=6755984, In bbox=2965497, Class 3/4=47726
#
# Processing file 35/148: SWOT_L2_HR_PIXC_025_318_155L_20241214T075007_20241214T075018_PIC2_01.nc
# Using dimension 'points' with 4322095 points
# Processing SWOT_L2_HR_PIXC_025_318_155L_20241214T075007_20241214T075018_PIC2_01.nc: Total=4322095, In bbox=2709137, Class 3/4=56080
#
# Processing file 36/148: SWOT_L2_HR_PIXC_011_165_154R_20240220T180731_20240220T180742_PIC0_01.nc
# Using dimension 'points' with 4801288 points
# Processing SWOT_L2_HR_PIXC_011_165_154R_20240220T180731_20240220T180742_PIC0_01.nc: Total=4801288, In bbox=961991, Class 3/4=12671
#
# Processing file 37/148: SWOT_L2_HR_PIXC_010_012_154R_20240125T101058_20240125T101109_PIC0_01.nc
# Using dimension 'points' with 3199484 points
# Processing SWOT_L2_HR_PIXC_010_012_154R_20240125T101058_20240125T101109_PIC0_01.nc: Total=3199484, In bbox=1865, Class 3/4=9
#
# Processing file 38/148: SWOT_L2_HR_PIXC_013_318_155L_20240407T224908_20240407T224919_PIC0_01.nc
# Using dimension 'points' with 7179234 points
# Processing SWOT_L2_HR_PIXC_013_318_155L_20240407T224908_20240407T224919_PIC0_01.nc: Total=7179234, In bbox=4128148, Class 3/4=224911
#
# Processing file 39/148: SWOT_L2_HR_PIXC_024_165_154R_20241117T235332_20241117T235343_PIC2_01.nc
# Using dimension 'points' with 5825824 points
# Processing SWOT_L2_HR_PIXC_024_165_154R_20241117T235332_20241117T235343_PIC2_01.nc: Total=5825824, In bbox=968203, Class 3/4=16794
#
# Processing file 40/148: SWOT_L2_HR_PIXC_024_318_156L_20241123T110513_20241123T110524_PIC2_01.nc
# Using dimension 'points' with 8751942 points
# Processing SWOT_L2_HR_PIXC_024_318_156L_20241123T110513_20241123T110524_PIC2_01.nc: Total=8751942, In bbox=3566075, Class 3/4=61292
#
# Status: Processed 40/148 files, found 1190171 points so far
#
# Processing file 41/148: SWOT_L2_HR_PIXC_009_165_153R_20240110T003710_20240110T003721_PIC0_01.nc
# Using dimension 'points' with 5692931 points
# Processing SWOT_L2_HR_PIXC_009_165_153R_20240110T003710_20240110T003721_PIC0_01.nc: Total=5692931, In bbox=528355, Class 3/4=16462
#
# Processing file 42/148: SWOT_L2_HR_PIXC_016_262_198L_20240607T131032_20240607T131043_PIC0_01.nc
# Using dimension 'points' with 101053 points
# Processing SWOT_L2_HR_PIXC_016_262_198L_20240607T131032_20240607T131043_PIC0_01.nc: Total=101053, In bbox=0, Class 3/4=0
#
# Processing file 43/148: SWOT_L2_HR_PIXC_016_165_154R_20240604T015254_20240604T015305_PIC0_01.nc
# Using dimension 'points' with 4811286 points
# Processing SWOT_L2_HR_PIXC_016_165_154R_20240604T015254_20240604T015305_PIC0_01.nc: Total=4811286, In bbox=937758, Class 3/4=11950
#
# Processing file 44/148: SWOT_L2_HR_PIXC_022_165_154R_20241007T062324_20241007T062335_PIC0_01.nc
# Using dimension 'points' with 4658600 points
# Processing SWOT_L2_HR_PIXC_022_165_154R_20241007T062324_20241007T062335_PIC0_01.nc: Total=4658600, In bbox=904269, Class 3/4=12408
#
# Processing file 45/148: SWOT_L2_HR_PIXC_021_165_153R_20240916T093806_20240916T093817_PIC0_01.nc
# Using dimension 'points' with 5690034 points
# Processing SWOT_L2_HR_PIXC_021_165_153R_20240916T093806_20240916T093817_PIC0_01.nc: Total=5690034, In bbox=648552, Class 3/4=23011
#
# Processing file 46/148: SWOT_L2_HR_PIXC_014_318_156L_20240428T193423_20240428T193434_PIC0_01.nc
# Using dimension 'points' with 5007836 points
# Processing SWOT_L2_HR_PIXC_014_318_156L_20240428T193423_20240428T193434_PIC0_01.nc: Total=5007836, In bbox=1371884, Class 3/4=24444
#
# Processing file 47/148: SWOT_L2_HR_PIXC_023_165_153R_20241028T030817_20241028T030829_PIC2_01.nc
# Using dimension 'points' with 5366946 points
# Processing SWOT_L2_HR_PIXC_023_165_153R_20241028T030817_20241028T030829_PIC2_01.nc: Total=5366946, In bbox=533127, Class 3/4=18175
#
# Processing file 48/148: SWOT_L2_HR_PIXC_016_318_155L_20240609T130423_20240609T130434_PIC0_01.nc
# Using dimension 'points' with 4712317 points
# Processing SWOT_L2_HR_PIXC_016_318_155L_20240609T130423_20240609T130434_PIC0_01.nc: Total=4712317, In bbox=2805572, Class 3/4=59222
#
# Processing file 49/148: SWOT_L2_HR_PIXC_025_012_154R_20241203T092709_20241203T092720_PIC2_01.nc
# Using dimension 'points' with 3189447 points
# Processing SWOT_L2_HR_PIXC_025_012_154R_20241203T092709_20241203T092720_PIC2_01.nc: Total=3189447, In bbox=1888, Class 3/4=8
#
# Processing file 50/148: SWOT_L2_HR_PIXC_026_012_155R_20241224T061223_20241224T061234_PIC2_01.nc
# Using dimension 'points' with 4637381 points
# Processing SWOT_L2_HR_PIXC_026_012_155R_20241224T061223_20241224T061234_PIC2_01.nc: Total=4637381, In bbox=88357, Class 3/4=765
#
# Status: Processed 50/148 files, found 1356616 points so far
#
# Processing file 51/148: SWOT_L2_HR_PIXC_025_165_154L_20241208T203836_20241208T203847_PIC2_01.nc
# Using dimension 'points' with 3004742 points
# Processing SWOT_L2_HR_PIXC_025_165_154L_20241208T203836_20241208T203847_PIC2_01.nc: Total=3004742, In bbox=1174533, Class 3/4=22750
#
# Processing file 52/148: SWOT_L2_HR_PIXC_016_262_197R_20240607T131022_20240607T131033_PIC0_01.nc
# Using dimension 'points' with 99031 points
# Processing SWOT_L2_HR_PIXC_016_262_197R_20240607T131022_20240607T131033_PIC0_01.nc: Total=99031, In bbox=0, Class 3/4=0
#
# Processing file 53/148: SWOT_L2_HR_PIXC_015_318_155L_20240519T161918_20240519T161929_PIC0_01.nc
# Using dimension 'points' with 5687184 points
# Processing SWOT_L2_HR_PIXC_015_318_155L_20240519T161918_20240519T161929_PIC0_01.nc: Total=5687184, In bbox=3408910, Class 3/4=100064
#
# Processing file 54/148: SWOT_L2_HR_PIXC_010_165_154L_20240130T212226_20240130T212237_PIC0_01.nc
# Using dimension 'points' with 3081398 points
# Processing SWOT_L2_HR_PIXC_010_165_154L_20240130T212226_20240130T212237_PIC0_01.nc: Total=3081398, In bbox=1229921, Class 3/4=27136
#
# Processing file 55/148: SWOT_L2_HR_PIXC_011_318_156L_20240226T051911_20240226T051922_PIC0_01.nc
# Using dimension 'points' with 6881122 points
# Processing SWOT_L2_HR_PIXC_011_318_156L_20240226T051911_20240226T051922_PIC0_01.nc: Total=6881122, In bbox=2755741, Class 3/4=37853
#
# Processing file 56/148: SWOT_L2_HR_PIXC_015_165_154R_20240514T050748_20240514T050759_PIC0_01.nc
# Using dimension 'points' with 5649090 points
# Processing SWOT_L2_HR_PIXC_015_165_154R_20240514T050748_20240514T050759_PIC0_01.nc: Total=5649090, In bbox=963923, Class 3/4=16300
#
# Processing file 57/148: SWOT_L2_HR_PIXC_009_165_153R_20240110T003710_20240110T003721_PGC0_01.nc
# Using dimension 'points' with 5692036 points
# Processing SWOT_L2_HR_PIXC_009_165_153R_20240110T003710_20240110T003721_PGC0_01.nc: Total=5692036, In bbox=527952, Class 3/4=16426
#
# Processing file 58/148: SWOT_L2_HR_PIXC_010_318_156L_20240205T083406_20240205T083417_PIC0_01.nc
# Using dimension 'points' with 6563603 points
# Processing SWOT_L2_HR_PIXC_010_318_156L_20240205T083406_20240205T083417_PIC0_01.nc: Total=6563603, In bbox=2730960, Class 3/4=38162
#
# Processing file 59/148: SWOT_L2_HR_PIXC_021_325_109R_20240922T024219_20240922T024231_PIC0_01.nc
# Using dimension 'points' with 0 points
# Processing SWOT_L2_HR_PIXC_021_325_109R_20240922T024219_20240922T024231_PIC0_01.nc: Total=0, In bbox=0, Class 3/4=0
#
# Processing file 60/148: SWOT_L2_HR_PIXC_023_318_155L_20241102T141957_20241102T142008_PIC2_01.nc
# Using dimension 'points' with 4379327 points
# Processing SWOT_L2_HR_PIXC_023_318_155L_20241102T141957_20241102T142008_PIC2_01.nc: Total=4379327, In bbox=2683525, Class 3/4=54872
#
# Status: Processed 60/148 files, found 1670179 points so far
#
# Processing file 61/148: SWOT_L2_HR_PIXC_014_012_156R_20240417T211136_20240417T211147_PIC0_01.nc
# Using dimension 'points' with 6403977 points
# Processing SWOT_L2_HR_PIXC_014_012_156R_20240417T211136_20240417T211147_PIC0_01.nc: Total=6403977, In bbox=0, Class 3/4=0
#
# Processing file 62/148: SWOT_L2_HR_PIXC_018_012_156R_20240710T081153_20240710T081204_PIC0_01.nc
# Using dimension 'points' with 5087000 points
# Processing SWOT_L2_HR_PIXC_018_012_156R_20240710T081153_20240710T081204_PIC0_01.nc: Total=5087000, In bbox=0, Class 3/4=0
#
# Processing file 63/148: SWOT_L2_HR_PIXC_024_012_155R_20241112T124214_20241112T124225_PIC2_01.nc
# Using dimension 'points' with 4510612 points
# Processing SWOT_L2_HR_PIXC_024_012_155R_20241112T124214_20241112T124225_PIC2_01.nc: Total=4510612, In bbox=71522, Class 3/4=651
#
# Processing file 64/148: SWOT_L2_HR_PIXC_013_165_154R_20240402T113738_20240402T113749_PIC0_01.nc
# Using dimension 'points' with 5763397 points
# Processing SWOT_L2_HR_PIXC_013_165_154R_20240402T113738_20240402T113749_PIC0_01.nc: Total=5763397, In bbox=943988, Class 3/4=16091
#
# Processing file 65/148: SWOT_L2_HR_PIXC_010_012_156R_20240125T101118_20240125T101129_PIC0_01.nc
# Using dimension 'points' with 5056173 points
# Processing SWOT_L2_HR_PIXC_010_012_156R_20240125T101118_20240125T101129_PIC0_01.nc: Total=5056173, In bbox=0, Class 3/4=0
#
# Processing file 66/148: SWOT_L2_HR_PIXC_022_318_156L_20241012T173503_20241012T173514_PIC0_01.nc
# Using dimension 'points' with 6543985 points
# Processing SWOT_L2_HR_PIXC_022_318_156L_20241012T173503_20241012T173514_PIC0_01.nc: Total=6543985, In bbox=2657936, Class 3/4=37764
#
# Processing file 67/148: SWOT_L2_HR_PIXC_012_012_155R_20240307T034117_20240307T034128_PIC0_01.nc
# Using dimension 'points' with 4269843 points
# Processing SWOT_L2_HR_PIXC_012_012_155R_20240307T034117_20240307T034128_PIC0_01.nc: Total=4269843, In bbox=76266, Class 3/4=677
#
# Processing file 68/148: SWOT_L2_HR_PIXC_009_165_154L_20240110T003720_20240110T003731_PGC0_01.nc
# Using dimension 'points' with 3577539 points
# Processing SWOT_L2_HR_PIXC_009_165_154L_20240110T003720_20240110T003731_PGC0_01.nc: Total=3577539, In bbox=1430632, Class 3/4=38890
#
# Processing file 69/148: SWOT_L2_HR_PIXC_011_012_154R_20240215T065603_20240215T065614_PIC0_01.nc
# Using dimension 'points' with 3277260 points
# Processing SWOT_L2_HR_PIXC_011_012_154R_20240215T065603_20240215T065614_PIC0_01.nc: Total=3277260, In bbox=1959, Class 3/4=10
#
# Processing file 70/148: SWOT_L2_HR_PIXC_023_012_154R_20241022T155700_20241022T155711_PIC2_01.nc
# Using dimension 'points' with 2784926 points
# Processing SWOT_L2_HR_PIXC_023_012_154R_20241022T155700_20241022T155711_PIC2_01.nc: Total=2784926, In bbox=1475, Class 3/4=8
#
# Status: Processed 70/148 files, found 1764270 points so far
#
# Processing file 71/148: SWOT_L2_HR_PIXC_010_012_155R_20240125T101108_20240125T101119_PIC0_01.nc
# Using dimension 'points' with 4053156 points
# Processing SWOT_L2_HR_PIXC_010_012_155R_20240125T101108_20240125T101119_PIC0_01.nc: Total=4053156, In bbox=72988, Class 3/4=554
#
# Processing file 72/148: SWOT_L2_HR_PIXC_026_012_154R_20241224T061213_20241224T061224_PIC2_01.nc
# Using dimension 'points' with 3072780 points
# Processing SWOT_L2_HR_PIXC_026_012_154R_20241224T061213_20241224T061224_PIC2_01.nc: Total=3072780, In bbox=1619, Class 3/4=5
#
# Processing file 73/148: SWOT_L2_HR_PIXC_023_165_154L_20241028T030827_20241028T030839_PIC2_01.nc
# Using dimension 'points' with 3486999 points
# Processing SWOT_L2_HR_PIXC_023_165_154L_20241028T030827_20241028T030839_PIC2_01.nc: Total=3486999, In bbox=1281857, Class 3/4=27625
#
# Processing file 74/148: SWOT_L2_HR_PIXC_016_262_196L_20240607T131012_20240607T131023_PIC0_01.nc
# Using dimension 'points' with 173774 points
# Processing SWOT_L2_HR_PIXC_016_262_196L_20240607T131012_20240607T131023_PIC0_01.nc: Total=173774, In bbox=0, Class 3/4=0
#
# Processing file 75/148: SWOT_L2_HR_PIXC_016_262_197L_20240607T131022_20240607T131033_PIC0_01.nc
# Using dimension 'points' with 188173 points
# Processing SWOT_L2_HR_PIXC_016_262_197L_20240607T131022_20240607T131033_PIC0_01.nc: Total=188173, In bbox=0, Class 3/4=0
#
# Processing file 76/148: SWOT_L2_HR_PIXC_022_165_154L_20241007T062324_20241007T062335_PIC0_01.nc
# Using dimension 'points' with 3277021 points
# Processing SWOT_L2_HR_PIXC_022_165_154L_20241007T062324_20241007T062335_PIC0_01.nc: Total=3277021, In bbox=1251622, Class 3/4=23376
#
# Processing file 77/148: SWOT_L2_HR_PIXC_009_165_154R_20240110T003720_20240110T003731_PIC0_01.nc
# Using dimension 'points' with 5012975 points
# Processing SWOT_L2_HR_PIXC_009_165_154R_20240110T003720_20240110T003731_PIC0_01.nc: Total=5012975, In bbox=863426, Class 3/4=11469
#
# Processing file 78/148: SWOT_L2_HR_PIXC_009_012_156R_20240104T132612_20240104T132623_PIC0_01.nc
# Using dimension 'points' with 5072618 points
# Processing SWOT_L2_HR_PIXC_009_012_156R_20240104T132612_20240104T132623_PIC0_01.nc: Total=5072618, In bbox=0, Class 3/4=0
#
# Processing file 79/148: SWOT_L2_HR_PIXC_025_012_156R_20241203T092729_20241203T092740_PIC2_01.nc
# Using dimension 'points' with 5241603 points
# Processing SWOT_L2_HR_PIXC_025_012_156R_20241203T092729_20241203T092740_PIC2_01.nc: Total=5241603, In bbox=0, Class 3/4=0
#
# Processing file 80/148: SWOT_L2_HR_PIXC_009_318_155L_20240115T114850_20240115T114901_PGC0_01.nc
# Using dimension 'points' with 5300012 points
# Processing SWOT_L2_HR_PIXC_009_318_155L_20240115T114850_20240115T114901_PGC0_01.nc: Total=5300012, In bbox=3120942, Class 3/4=85403
#
# Status: Processed 80/148 files, found 1912702 points so far
#
# Processing file 81/148: SWOT_L2_HR_PIXC_018_165_153R_20240715T192252_20240715T192303_PIC0_01.nc
# Using dimension 'points' with 5846275 points
# Processing SWOT_L2_HR_PIXC_018_165_153R_20240715T192252_20240715T192303_PIC0_01.nc: Total=5846275, In bbox=626960, Class 3/4=20350
#
# Processing file 82/148: SWOT_L2_HR_PIXC_025_165_153R_20241208T203826_20241208T203837_PIC2_01.nc
# Using dimension 'points' with 5821084 points
# Processing SWOT_L2_HR_PIXC_025_165_153R_20241208T203826_20241208T203837_PIC2_01.nc: Total=5821084, In bbox=602174, Class 3/4=16847
#
# Processing file 83/148: SWOT_L2_HR_PIXC_016_165_153R_20240604T015244_20240604T015255_PIC0_01.nc
# Using dimension 'points' with 6274785 points
# Processing SWOT_L2_HR_PIXC_016_165_153R_20240604T015244_20240604T015255_PIC0_01.nc: Total=6274785, In bbox=649947, Class 3/4=25439
#
# Processing file 84/148: SWOT_L2_HR_PIXC_009_012_155R_20240104T132602_20240104T132613_PGC0_01.nc
# Using dimension 'points' with 3947302 points
# Processing SWOT_L2_HR_PIXC_009_012_155R_20240104T132602_20240104T132613_PGC0_01.nc: Total=3947302, In bbox=70558, Class 3/4=552
#
# Processing file 85/148: SWOT_L2_HR_PIXC_022_012_154R_20241001T191156_20241001T191207_PIC0_01.nc
# Using dimension 'points' with 2727968 points
# Processing SWOT_L2_HR_PIXC_022_012_154R_20241001T191156_20241001T191207_PIC0_01.nc: Total=2727968, In bbox=2081, Class 3/4=9
#
# Processing file 86/148: SWOT_L2_HR_PIXC_011_318_155L_20240226T051901_20240226T051912_PIC0_01.nc
# Using dimension 'points' with 4595943 points
# Processing SWOT_L2_HR_PIXC_011_318_155L_20240226T051901_20240226T051912_PIC0_01.nc: Total=4595943, In bbox=2958717, Class 3/4=70858
#
# Processing file 87/148: SWOT_L2_HR_PIXC_015_165_154L_20240514T050748_20240514T050759_PIC0_01.nc
# Using dimension 'points' with 3713910 points
# Processing SWOT_L2_HR_PIXC_015_165_154L_20240514T050748_20240514T050759_PIC0_01.nc: Total=3713910, In bbox=1417230, Class 3/4=30448
#
# Processing file 88/148: SWOT_L2_HR_PIXC_021_165_154L_20240916T093816_20240916T093827_PIC0_01.nc
# Using dimension 'points' with 2852948 points
# Processing SWOT_L2_HR_PIXC_021_165_154L_20240916T093816_20240916T093827_PIC0_01.nc: Total=2852948, In bbox=1161847, Class 3/4=21800
#
# Processing file 89/148: SWOT_L2_HR_PIXC_019_318_155L_20240811T031937_20240811T031948_PIC0_01.nc
# Using dimension 'points' with 4677393 points
# Processing SWOT_L2_HR_PIXC_019_318_155L_20240811T031937_20240811T031948_PIC0_01.nc: Total=4677393, In bbox=2851025, Class 3/4=64667
#
# Processing file 90/148: SWOT_L2_HR_PIXC_011_012_156R_20240215T065623_20240215T065634_PIC0_01.nc
# Using dimension 'points' with 5045524 points
# Processing SWOT_L2_HR_PIXC_011_012_156R_20240215T065623_20240215T065634_PIC0_01.nc: Total=5045524, In bbox=0, Class 3/4=0
#
# Status: Processed 90/148 files, found 2163672 points so far
#
# Processing file 91/148: SWOT_L2_HR_PIXC_025_318_156L_20241214T075017_20241214T075028_PIC2_01.nc
# Using dimension 'points' with 6557545 points
# Processing SWOT_L2_HR_PIXC_025_318_156L_20241214T075017_20241214T075028_PIC2_01.nc: Total=6557545, In bbox=2732535, Class 3/4=36954
#
# Processing file 92/148: SWOT_L2_HR_PIXC_011_165_153R_20240220T180721_20240220T180732_PIC0_01.nc
# Using dimension 'points' with 5879917 points
# Processing SWOT_L2_HR_PIXC_011_165_153R_20240220T180721_20240220T180732_PIC0_01.nc: Total=5879917, In bbox=564857, Class 3/4=17525
#
# Processing file 93/148: SWOT_L2_HR_PIXC_010_012_156R_20240125T101118_20240125T101129_PGC0_01.nc
# Using dimension 'points' with 5056364 points
# Processing SWOT_L2_HR_PIXC_010_012_156R_20240125T101118_20240125T101129_PGC0_01.nc: Total=5056364, In bbox=0, Class 3/4=0
#
# Processing file 94/148: SWOT_L2_HR_PIXC_021_012_154R_20240910T222648_20240910T222659_PIC0_01.nc
# Using dimension 'points' with 3097696 points
# Processing SWOT_L2_HR_PIXC_021_012_154R_20240910T222648_20240910T222659_PIC0_01.nc: Total=3097696, In bbox=3014, Class 3/4=12
#
# Processing file 95/148: SWOT_L2_HR_PIXC_009_318_156L_20240115T114900_20240115T114911_PIC0_01.nc
# Using dimension 'points' with 8232731 points
# Processing SWOT_L2_HR_PIXC_009_318_156L_20240115T114900_20240115T114911_PIC0_01.nc: Total=8232731, In bbox=3543828, Class 3/4=57164
#
# Processing file 96/148: SWOT_L2_HR_PIXC_021_318_156L_20240921T204958_20240921T205009_PIC0_01.nc
# Using dimension 'points' with 6649051 points
# Processing SWOT_L2_HR_PIXC_021_318_156L_20240921T204958_20240921T205009_PIC0_01.nc: Total=6649051, In bbox=2716888, Class 3/4=37134
#
# Processing file 97/148: SWOT_L2_HR_PIXC_009_165_154R_20240110T003720_20240110T003731_PGC0_01.nc
# Using dimension 'points' with 5011860 points
# Processing SWOT_L2_HR_PIXC_009_165_154R_20240110T003720_20240110T003731_PGC0_01.nc: Total=5011860, In bbox=862502, Class 3/4=11466
#
# Processing file 98/148: SWOT_L2_HR_PIXC_013_318_156L_20240407T224918_20240407T224929_PIC0_01.nc
# Using dimension 'points' with 9035142 points
# Processing SWOT_L2_HR_PIXC_013_318_156L_20240407T224918_20240407T224929_PIC0_01.nc: Total=9035142, In bbox=3865777, Class 3/4=80714
#
# Processing file 99/148: SWOT_L2_HR_PIXC_020_012_156R_20240821T014202_20240821T014213_PIC0_01.nc
# Using dimension 'points' with 4740712 points
# Processing SWOT_L2_HR_PIXC_020_012_156R_20240821T014202_20240821T014213_PIC0_01.nc: Total=4740712, In bbox=1, Class 3/4=0
#
# Processing file 100/148: SWOT_L2_HR_PIXC_014_165_154R_20240423T082244_20240423T082255_PIC0_01.nc
# Using dimension 'points' with 5871189 points
# Processing SWOT_L2_HR_PIXC_014_165_154R_20240423T082244_20240423T082255_PIC0_01.nc: Total=5871189, In bbox=828260, Class 3/4=26045
#
# Status: Processed 100/148 files, found 2430686 points so far
#
# Processing file 101/148: SWOT_L2_HR_PIXC_023_012_155R_20241022T155710_20241022T155721_PIC2_01.nc
# Using dimension 'points' with 4033470 points
# Processing SWOT_L2_HR_PIXC_023_012_155R_20241022T155710_20241022T155721_PIC2_01.nc: Total=4033470, In bbox=66530, Class 3/4=481
#
# Processing file 102/148: SWOT_L2_HR_PIXC_012_165_153R_20240312T145224_20240312T145235_PIC0_01.nc
# Using dimension 'points' with 6134714 points
# Processing SWOT_L2_HR_PIXC_012_165_153R_20240312T145224_20240312T145235_PIC0_01.nc: Total=6134714, In bbox=606758, Class 3/4=17948
#
# Processing file 103/148: SWOT_L2_HR_PIXC_013_012_154R_20240328T002610_20240328T002621_PIC0_01.nc
# Using dimension 'points' with 3199575 points
# Processing SWOT_L2_HR_PIXC_013_012_154R_20240328T002610_20240328T002621_PIC0_01.nc: Total=3199575, In bbox=1294, Class 3/4=6
#
# Processing file 104/148: SWOT_L2_HR_PIXC_020_165_154R_20240826T125310_20240826T125321_PIC0_01.nc
# Using dimension 'points' with 5529981 points
# Processing SWOT_L2_HR_PIXC_020_165_154R_20240826T125310_20240826T125321_PIC0_01.nc: Total=5529981, In bbox=969853, Class 3/4=14345
#
# Processing file 105/148: SWOT_L2_HR_PIXC_015_012_154R_20240508T175620_20240508T175631_PIC0_01.nc
# Using dimension 'points' with 3576551 points
# Processing SWOT_L2_HR_PIXC_015_012_154R_20240508T175620_20240508T175631_PIC0_01.nc: Total=3576551, In bbox=2772, Class 3/4=330
#
# Processing file 106/148: SWOT_L2_HR_PIXC_013_165_153R_20240402T113728_20240402T113739_PIC0_01.nc
# Using dimension 'points' with 7455646 points
# Processing SWOT_L2_HR_PIXC_013_165_153R_20240402T113728_20240402T113739_PIC0_01.nc: Total=7455646, In bbox=803624, Class 3/4=29827
#
# Processing file 107/148: SWOT_L2_HR_PIXC_017_165_154R_20240624T223757_20240624T223808_PIC0_01.nc
# Using dimension 'points' with 4930987 points
# Processing SWOT_L2_HR_PIXC_017_165_154R_20240624T223757_20240624T223808_PIC0_01.nc: Total=4930987, In bbox=951064, Class 3/4=12881
#
# Processing file 108/148: SWOT_L2_HR_PIXC_017_165_154L_20240624T223757_20240624T223808_PIC0_01.nc
# Using dimension 'points' with 3241406 points
# Processing SWOT_L2_HR_PIXC_017_165_154L_20240624T223757_20240624T223808_PIC0_01.nc: Total=3241406, In bbox=1198052, Class 3/4=21352
#
# Processing file 109/148: SWOT_L2_HR_PIXC_019_318_156L_20240811T031947_20240811T031958_PIC0_01.nc
# Using dimension 'points' with 7495109 points
# Processing SWOT_L2_HR_PIXC_019_318_156L_20240811T031947_20240811T031958_PIC0_01.nc: Total=7495109, In bbox=3165440, Class 3/4=53187
#
# Processing file 110/148: SWOT_L2_HR_PIXC_009_012_154R_20240104T132552_20240104T132603_PGC0_01.nc
# Using dimension 'points' with 3016982 points
# Processing SWOT_L2_HR_PIXC_009_012_154R_20240104T132552_20240104T132603_PGC0_01.nc: Total=3016982, In bbox=1499, Class 3/4=5
#
# Status: Processed 110/148 files, found 2581048 points so far
#
# Processing file 111/148: SWOT_L2_HR_PIXC_017_318_155L_20240630T094927_20240630T094938_PIC0_01.nc
# Using dimension 'points' with 4350019 points
# Processing SWOT_L2_HR_PIXC_017_318_155L_20240630T094927_20240630T094938_PIC0_01.nc: Total=4350019, In bbox=2680269, Class 3/4=56182
#
# Processing file 112/148: SWOT_L2_HR_PIXC_009_318_156L_20240115T114900_20240115T114911_PGC0_01.nc
# Using dimension 'points' with 8225971 points
# Processing SWOT_L2_HR_PIXC_009_318_156L_20240115T114900_20240115T114911_PGC0_01.nc: Total=8225971, In bbox=3539772, Class 3/4=56963
#
# Processing file 113/148: SWOT_L2_HR_PIXC_016_012_155R_20240529T144135_20240529T144146_PIC0_01.nc
# Using dimension 'points' with 4171103 points
# Processing SWOT_L2_HR_PIXC_016_012_155R_20240529T144135_20240529T144146_PIC0_01.nc: Total=4171103, In bbox=63322, Class 3/4=528
#
# Processing file 114/148: SWOT_L2_HR_PIXC_024_165_154L_20241117T235332_20241117T235343_PIC2_01.nc
# Using dimension 'points' with 3572896 points
# Processing SWOT_L2_HR_PIXC_024_165_154L_20241117T235332_20241117T235343_PIC2_01.nc: Total=3572896, In bbox=1354170, Class 3/4=28796
#
# Processing file 115/148: SWOT_L2_HR_PIXC_022_012_156R_20241001T191216_20241001T191227_PIC0_01.nc
# Using dimension 'points' with 4476308 points
# Processing SWOT_L2_HR_PIXC_022_012_156R_20241001T191216_20241001T191227_PIC0_01.nc: Total=4476308, In bbox=0, Class 3/4=0
#
# Processing file 116/148: SWOT_L2_HR_PIXC_020_318_155L_20240901T000441_20240901T000452_PIC0_01.nc
# Using dimension 'points' with 4519550 points
# Processing SWOT_L2_HR_PIXC_020_318_155L_20240901T000441_20240901T000452_PIC0_01.nc: Total=4519550, In bbox=2808841, Class 3/4=65272
#
# Processing file 117/148: SWOT_L2_HR_PIXC_018_012_155R_20240710T081143_20240710T081154_PIC0_01.nc
# Using dimension 'points' with 4273376 points
# Processing SWOT_L2_HR_PIXC_018_012_155R_20240710T081143_20240710T081154_PIC0_01.nc: Total=4273376, In bbox=78511, Class 3/4=748
#
# Processing file 118/148: SWOT_L2_HR_PIXC_015_012_156R_20240508T175640_20240508T175651_PIC0_01.nc
# Using dimension 'points' with 8201295 points
# Processing SWOT_L2_HR_PIXC_015_012_156R_20240508T175640_20240508T175651_PIC0_01.nc: Total=8201295, In bbox=1, Class 3/4=0
#
# Processing file 119/148: SWOT_L2_HR_PIXC_010_012_154R_20240125T101058_20240125T101109_PGC0_01.nc
# Using dimension 'points' with 3199243 points
# Processing SWOT_L2_HR_PIXC_010_012_154R_20240125T101058_20240125T101109_PGC0_01.nc: Total=3199243, In bbox=1865, Class 3/4=9
#
# Processing file 120/148: SWOT_L2_HR_PIXC_011_012_155R_20240215T065613_20240215T065624_PIC0_01.nc
# Using dimension 'points' with 4178722 points
# Processing SWOT_L2_HR_PIXC_011_012_155R_20240215T065613_20240215T065624_PIC0_01.nc: Total=4178722, In bbox=80015, Class 3/4=665
#
# Status: Processed 120/148 files, found 2790211 points so far
#
# Processing file 121/148: SWOT_L2_HR_PIXC_020_165_153R_20240826T125300_20240826T125311_PIC0_01.nc
# Using dimension 'points' with 5674251 points
# Processing SWOT_L2_HR_PIXC_020_165_153R_20240826T125300_20240826T125311_PIC0_01.nc: Total=5674251, In bbox=647136, Class 3/4=22917
#
# Processing file 122/148: SWOT_L2_HR_PIXC_017_012_155R_20240619T112640_20240619T112651_PIC0_01.nc
# Using dimension 'points' with 3937691 points
# Processing SWOT_L2_HR_PIXC_017_012_155R_20240619T112640_20240619T112651_PIC0_01.nc: Total=3937691, In bbox=69961, Class 3/4=539
#
# Processing file 123/148: SWOT_L2_HR_PIXC_013_012_155R_20240328T002620_20240328T002631_PIC0_01.nc
# Using dimension 'points' with 3823831 points
# Processing SWOT_L2_HR_PIXC_013_012_155R_20240328T002620_20240328T002631_PIC0_01.nc: Total=3823831, In bbox=70355, Class 3/4=628
#
# Processing file 124/148: SWOT_L2_HR_PIXC_023_165_154R_20241028T030827_20241028T030838_PIC2_01.nc
# Using dimension 'points' with 4822406 points
# Processing SWOT_L2_HR_PIXC_023_165_154R_20241028T030827_20241028T030838_PIC2_01.nc: Total=4822406, In bbox=899451, Class 3/4=12273
#
# Processing file 125/148: SWOT_L2_HR_PIXC_009_165_154L_20240110T003720_20240110T003731_PIC0_01.nc
# Using dimension 'points' with 3577158 points
# Processing SWOT_L2_HR_PIXC_009_165_154L_20240110T003720_20240110T003731_PIC0_01.nc: Total=3577158, In bbox=1429688, Class 3/4=38728
#
# Processing file 126/148: SWOT_L2_HR_PIXC_021_012_156R_20240910T222708_20240910T222719_PIC0_01.nc
# Using dimension 'points' with 4703984 points
# Processing SWOT_L2_HR_PIXC_021_012_156R_20240910T222708_20240910T222719_PIC0_01.nc: Total=4703984, In bbox=2, Class 3/4=0
#
# Processing file 127/148: SWOT_L2_HR_PIXC_009_012_156R_20240104T132612_20240104T132623_PGC0_01.nc
# Using dimension 'points' with 5072944 points
# Processing SWOT_L2_HR_PIXC_009_012_156R_20240104T132612_20240104T132623_PGC0_01.nc: Total=5072944, In bbox=0, Class 3/4=0
#
# Processing file 128/148: SWOT_L2_HR_PIXC_018_318_155L_20240721T063432_20240721T063443_PIC0_02.nc
# Using dimension 'points' with 4748721 points
# Processing SWOT_L2_HR_PIXC_018_318_155L_20240721T063432_20240721T063443_PIC0_02.nc: Total=4748721, In bbox=2904040, Class 3/4=67818
#
# Processing file 129/148: SWOT_L2_HR_PIXC_022_165_153R_20241007T062314_20241007T062325_PIC0_01.nc
# Using dimension 'points' with 5360452 points
# Processing SWOT_L2_HR_PIXC_022_165_153R_20241007T062314_20241007T062325_PIC0_01.nc: Total=5360452, In bbox=626256, Class 3/4=21126
#
# Processing file 130/148: SWOT_L2_HR_PIXC_014_165_154L_20240423T082244_20240423T082255_PIC0_01.nc
# Using dimension 'points' with 4273155 points
# Processing SWOT_L2_HR_PIXC_014_165_154L_20240423T082244_20240423T082255_PIC0_01.nc: Total=4273155, In bbox=1546362, Class 3/4=56476
#
# Status: Processed 130/148 files, found 3010716 points so far
#
# Processing file 131/148: SWOT_L2_HR_PIXC_011_165_154L_20240220T180731_20240220T180742_PIC0_01.nc
# Using dimension 'points' with 3129797 points
# Processing SWOT_L2_HR_PIXC_011_165_154L_20240220T180731_20240220T180742_PIC0_01.nc: Total=3129797, In bbox=1249763, Class 3/4=34012
#
# Processing file 132/148: SWOT_L2_HR_PIXC_022_012_155R_20241001T191206_20241001T191217_PIC0_01.nc
# Using dimension 'points' with 3962161 points
# Processing SWOT_L2_HR_PIXC_022_012_155R_20241001T191206_20241001T191217_PIC0_01.nc: Total=3962161, In bbox=71685, Class 3/4=560
#
# Processing file 133/148: SWOT_L2_HR_PIXC_014_318_155L_20240428T193413_20240428T193424_PIC0_01.nc
# Using dimension 'points' with 5347490 points
# Processing SWOT_L2_HR_PIXC_014_318_155L_20240428T193413_20240428T193424_PIC0_01.nc: Total=5347490, In bbox=2454388, Class 3/4=78733
#
# Processing file 134/148: SWOT_L2_HR_PIXC_010_165_154R_20240130T212226_20240130T212237_PIC0_01.nc
# Using dimension 'points' with 4951710 points
# Processing SWOT_L2_HR_PIXC_010_165_154R_20240130T212226_20240130T212237_PIC0_01.nc: Total=4951710, In bbox=989412, Class 3/4=12053
#
# Processing file 135/148: SWOT_L2_HR_PIXC_018_165_154R_20240715T192302_20240715T192313_PIC0_01.nc
# Using dimension 'points' with 4769844 points
# Processing SWOT_L2_HR_PIXC_018_165_154R_20240715T192302_20240715T192313_PIC0_01.nc: Total=4769844, In bbox=942691, Class 3/4=12663
#
# Processing file 136/148: SWOT_L2_HR_PIXC_024_318_155L_20241123T110503_20241123T110514_PIC2_01.nc
# Using dimension 'points' with 5262438 points
# Processing SWOT_L2_HR_PIXC_024_318_155L_20241123T110503_20241123T110514_PIC2_01.nc: Total=5262438, In bbox=3212791, Class 3/4=87419
#
# Processing file 137/148: SWOT_L2_HR_PIXC_016_165_154L_20240604T015254_20240604T015305_PIC0_01.nc
# Using dimension 'points' with 3245956 points
# Processing SWOT_L2_HR_PIXC_016_165_154L_20240604T015254_20240604T015305_PIC0_01.nc: Total=3245956, In bbox=1155626, Class 3/4=20561
#
# Processing file 138/148: SWOT_L2_HR_PIXC_024_012_154R_20241112T124204_20241112T124215_PIC2_01.nc
# Using dimension 'points' with 3332659 points
# Processing SWOT_L2_HR_PIXC_024_012_154R_20241112T124204_20241112T124215_PIC2_01.nc: Total=3332659, In bbox=319, Class 3/4=1
#
# Processing file 139/148: SWOT_L2_HR_PIXC_023_012_156R_20241022T155720_20241022T155731_PIC2_01.nc
# Using dimension 'points' with 4869281 points
# Processing SWOT_L2_HR_PIXC_023_012_156R_20241022T155720_20241022T155731_PIC2_01.nc: Total=4869281, In bbox=0, Class 3/4=0
#
# Processing file 140/148: SWOT_L2_HR_PIXC_016_012_154R_20240529T144125_20240529T144136_PIC0_01.nc
# Using dimension 'points' with 2904025 points
# Processing SWOT_L2_HR_PIXC_016_012_154R_20240529T144125_20240529T144136_PIC0_01.nc: Total=2904025, In bbox=2394, Class 3/4=14
#
# Status: Processed 140/148 files, found 3256732 points so far
#
# Processing file 141/148: SWOT_L2_HR_PIXC_009_012_155R_20240104T132602_20240104T132613_PIC0_01.nc
# Using dimension 'points' with 3948004 points
# Processing SWOT_L2_HR_PIXC_009_012_155R_20240104T132602_20240104T132613_PIC0_01.nc: Total=3948004, In bbox=70693, Class 3/4=554
#
# Processing file 142/148: SWOT_L2_HR_PIXC_021_012_155R_20240910T222658_20240910T222709_PIC0_01.nc
# Using dimension 'points' with 4238801 points
# Processing SWOT_L2_HR_PIXC_021_012_155R_20240910T222658_20240910T222709_PIC0_01.nc: Total=4238801, In bbox=86898, Class 3/4=753
#
# Processing file 143/148: SWOT_L2_HR_PIXC_017_012_154R_20240619T112630_20240619T112641_PIC0_01.nc
# Using dimension 'points' with 2512603 points
# Processing SWOT_L2_HR_PIXC_017_012_154R_20240619T112630_20240619T112641_PIC0_01.nc: Total=2512603, In bbox=1916, Class 3/4=9
#
# Processing file 144/148: SWOT_L2_HR_PIXC_016_012_156R_20240529T144145_20240529T144156_PIC0_01.nc
# Using dimension 'points' with 5492350 points
# Processing SWOT_L2_HR_PIXC_016_012_156R_20240529T144145_20240529T144156_PIC0_01.nc: Total=5492350, In bbox=1, Class 3/4=0
#
# Processing file 145/148: SWOT_L2_HR_PIXC_013_165_154L_20240402T113738_20240402T113749_PIC0_01.nc
# Using dimension 'points' with 3488949 points
# Processing SWOT_L2_HR_PIXC_013_165_154L_20240402T113738_20240402T113749_PIC0_01.nc: Total=3488949, In bbox=1518788, Class 3/4=62875
#
# Processing file 146/148: SWOT_L2_HR_PIXC_016_262_198R_20240607T131032_20240607T131043_PIC0_01.nc
# Using dimension 'points' with 24609 points
# Processing SWOT_L2_HR_PIXC_016_262_198R_20240607T131032_20240607T131043_PIC0_01.nc: Total=24609, In bbox=0, Class 3/4=0
#
# Processing file 147/148: SWOT_L2_HR_PIXC_012_165_154L_20240312T145234_20240312T145245_PIC0_01.nc
# Using dimension 'points' with 3083860 points
# Processing SWOT_L2_HR_PIXC_012_165_154L_20240312T145234_20240312T145245_PIC0_01.nc: Total=3083860, In bbox=1284860, Class 3/4=35669
#
# Processing file 148/148: SWOT_L2_HR_PIXC_010_165_153R_20240130T212216_20240130T212227_PIC0_01.nc
# Using dimension 'points' with 5635213 points
# Processing SWOT_L2_HR_PIXC_010_165_153R_20240130T212216_20240130T212227_PIC0_01.nc: Total=5635213, In bbox=569196, Class 3/4=17313
#
# Status: Processed 148/148 files, found 3373905 points so far
#
# Processing complete! Found 3373905 points in 148 files.

# %%
# Check if we should convert to GeoJSON
if total_points > 0:
    # Ask user if they want to convert
    convert = input(f"Convert {total_points} points to GeoJSON? This might require significant memory (y/n): ")
    
    if convert.lower() == 'y':
        try:
            # Create output directory
            output_dir = Path(config['data_dir']) / 'output'
            output_dir.mkdir(exist_ok=True)
            
            # Create GeoJSON filename
            geojson_file = output_dir / f'subset_class3and4_{datetime.now().strftime("%Y%m%d%H%M%S")}.geojson'
            
            print(f"Loading data from {output_file}...")
            df = pd.read_parquet(output_file)
            print(f"Converting {len(df)} points to GeoDataFrame...")
            
            # Create GeoDataFrame
            gdf = gpd.GeoDataFrame(
                df, 
                geometry=gpd.points_from_xy(df.longitude, df.latitude),
                crs="EPSG:4326"
            )
            
            # Fix for index64 pandas issue
            gdf["row_id"] = gdf.index + 1
            gdf.reset_index(drop=True, inplace=True)
            gdf.set_index("row_id", inplace=True)
            
            print(f"Saving to {geojson_file}...")
            gdf.to_file(geojson_file, driver='GeoJSON')
            print(f"GeoJSON file saved to {geojson_file}")
            
        except Exception as e:
            print(f"Error converting to GeoJSON: {str(e)}")
else:
    print("No points found, skipping GeoJSON conversion.")
# Out:
# Loading data from data/processed_data.parquet...
# Converting 3373905 points to GeoDataFrame...
# Saving to data/output/subset_class3and4_20250414133915.geojson...
# GeoJSON file saved to data/output/subset_class3and4_20250414133915.geojson
